# %%
def alternatingSort(a):
    b=len(a)/2
    for i in range(0,int(b)):
        print(a[i])
    for c in range(int(len(a)),int(b)):
        print(a[c])
    return

# %%
alternatingSort([1, 3, 5, 6, 4, 2])
# Out:
# 1
# 3
# 5

# %%
strr="hello"

# %%
a=strr[::-1]

# %%
a==strr
# Out:
# False

# %%
inputArray=[2,3,5,2,3]
for i in range(len(inputArray),0):
    num=inputArray[]*inputArray[i-1]
    print(num)

# %%
for i in range(3):
        sum=4*i
        i = i+i
        print(sum)
# Out:
# 0
# 4
# 8

# %%
a=1
for i in range(3):
    sum=1+4*i
    
print(sum)
# Out:
# 9

# %%
a=[2,1,2,3,4,5]
a[:]
# Out:
# [2, 1, 2, 3, 4, 5]

# %%
class Node(object):
    def __init__(self, val):
        self.val = val
        self.next = None
class MyLinkedList:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.head=None
        self.tail=None
        self.size=0
    def get(self, index: int) -> None:
        """
        Get the value of the index-th node in the linked list. If the index is invalid, return -1.
        """
        if index<0 or index >= self.size:
            return -1
        if self.head==None:
            return -1
        a=self.head
        for i in range(index):
            a=a.next
        return a.val
        

    def addAtHead(self, val: int) -> None:
        """
        Add a node of value val before the first element of the linked list. After the insertion, the new node will be the first node of the linked list.
        """
        newHead=Node(val)
        newHead.next=self.head
        self.head=newHead
        self.size = self.size + 1

    def addAtTail(self, val: int) -> None:
        """
        Append a node of value val to the last element of the linked list.
        """
        a=self.head
        if a == None:
            self.head=Node(val)
        else:
            while a.next != None:
                a=a.next
            a.next=val
                
        
        self.size = self.size+1

    def addAtIndex(self, index: int, val: int) -> None:
        """
        Add a node of value val before the index-th node in the linked list. If index equals to the length of linked list, the node will be appended to the end of linked list. If index is greater than the length, the node will not be inserted.
        """
        
        if index < 0 or index > self.size:
            pass
        if index == self.size:
            self.addAtTail(val)

        if index == 0:
            self.addAtHead(val)
        else:
            a = self.head
            for i in range(index - 1):
                a = a.next
            node = Node(val)
            node.next = a.next
            a.next = node

            self.size += 1


    def deleteAtIndex(self, index: int) -> None:
        """
        Delete the index-th node in the linked list, if the index is valid.
        """
        if index < 0 or index >= self.size:
            return

        a = self.head
        if index == 0:
            self.head = a.next
        else:
            for i in range(index - 1):
                a = a.next
            a.next = a.next.next

        self.size -= 1
    def get_list(self):
        '''測試用，可回傳list'''
        if self.size != 0:
            return [self.get(item) for item in range(self.size)]
        else :
            return -1

# %%
obj=MyLinkedList()

# %%
obj.addAtHead(1)

# %%
obj.addAtIndex(1,2)

# %%
obj.size
# Out:
# 1

# %%
obj.get_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-5245adf46480> in <module>
# ----> 1 obj.get_list()
#
# <ipython-input-13-8644c725fdcb> in get_list(self)
#      92         '''測試用，可回傳list'''
#      93         if self.size != 0:
# ---> 94             return [self.get(item) for item in range(self.size)]
#      95         else :
#      96             return -1
#
# <ipython-input-13-8644c725fdcb> in <listcomp>(.0)
#      92         '''測試用，可回傳list'''
#      93         if self.size != 0:
# ---> 94             return [self.get(item) for item in range(self.size)]
#      95         else :
#      96             return -1
#
# <ipython-input-13-8644c725fdcb> in get(self, index)
#      23         for i in range(index):
#      24             a=a.next
# ---> 25         return a.val
#      26
#      27
#
# AttributeError: 'int' object has no attribute 'val'

# %%
from IPython.display import Image

# %%
Image(filename='C:/Users/User/Desktop/merge_sort.png')
